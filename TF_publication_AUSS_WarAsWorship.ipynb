# %% [markdown]
# # Prelude

# %%
# First, I have to laod different modules that I use for analyzing the data and for plotting:
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# %%
pd.set_option('display.max_rows', None)

# %%
# Second, I have to load the Text Fabric app
from tf.fabric import Fabric
from tf.app import use

# %%
# Now we load the TF bhsa database
OT = use('etcbc/bhsa', version="2021", mod='CenterBLC/BHSaddons/tf')
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv1.8=#eb1eef532de43783a548afed016937f55572bac6 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/app</span>
# <b title="local release">data:</b> <span title="rv1.8=#eb1eef532de43783a548afed016937f55572bac6 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/bhsa/tf/2021</span>
# <b title="local release">data:</b> <span title="rv1.0.1=#9508343aaf9f1dcbc401dc449da104286af5af32 offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#aba4367b49750089e4e4122415a77cac43bd97bc offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/phono/tf/2021</span>
# <b title="local release">data:</b> <span title="rv2.1=#f45f6cc3c4f933dba6e649f49cdb14a40dcf333f offline under /Users/oliverglanz/text-fabric-data/github">~/text-fabric-data/github/etcbc/parallels/tf/2021</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.3.0</a>, <a target="_blank" href="https://github.com/etcbc/bhsa/blob/master/app" title="etcbc/bhsa app">etcbc/bhsa/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://etcbc.github.io/bhsa/" title="provenance of BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis">etcbc - bhsa 2021</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/hebrew.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://etcbc.github.io/bhsa/features/0_home" title="etcbc - bhsa feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>39</td>
#     <td>10938.21</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>929</td>
#     <td>459.19</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>lex</th>
#     <td>9230</td>
#     <td>46.22</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>23213</td>
#     <td>18.38</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>half_verse</th>
#     <td>45179</td>
#     <td>9.44</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>63717</td>
#     <td>6.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence_atom</th>
#     <td>64514</td>
#     <td>6.61</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>88131</td>
#     <td>4.84</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause_atom</th>
#     <td>90704</td>
#     <td>4.70</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>253203</td>
#     <td>1.68</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>phrase_atom</th>
#     <td>267532</td>
#     <td>1.59</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>113850</td>
#     <td>1.42</td>
#     <td>38</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>426590</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>Parallel Passages</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat edge">
# <a target="_blank" href="https://nbviewer.jupyter.org/github/etcbc/parallels/blob/master/programs/parallels.ipynb" title="~/text-fabric-data/github/etcbc/parallels/tf/2021/crossref.tf">crossref</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 🆗 links between similar passages</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b><github>CenterBLC/BHSaddons/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_bhsa_word_order.tf">bol_bhsa_word_order</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ the sequence number of each word in the BHSa (1,2,3,...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_EN.tf">bol_dict_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ English glosses of the BibleOL Hebrew/Aramaic dictionary</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_ES.tf">bol_dict_ES</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ Spanish glosses of the BibleOL Hebrew/Aramaic dictionary</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_HebArm.tf">bol_dict_HebArm</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL Hebrew/Aramaic dictionary with homograph disambiguation (ברא I. ברא II)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_abc.tf">bol_dict_abc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ The dictionary sequence number of each word (1,2,3,...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/bol_dict_vc.tf">bol_dict_vc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL verbal classes (i-nun, ii-waw, ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/g_word_noaccent.tf">g_word_noaccent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ each text-realized word with consonants and vowels but no Masoretic signs (B.@R@>, >:ELOHIJM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/interlinear.tf">interlinear</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ BibleOL verbal classes (i-nun, ii-waw, ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/lex_cons.tf">lex_cons</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ each word in its consonantal form only and with not disambiguation (BR>, >LHJM)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/BHSaddons/tree/master/tf" title="~/text-fabric-data/github/CenterBLC/BHSaddons/tf/2021/strong.tf">strong</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ Strong's numbers</span>
#
# </div>
#
#     </div>
# </details>
#
# <details><summary><b>BHSA = Biblia Hebraica Stuttgartensia Amstelodamensis</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in Latin (Genesis; Numeri; Reges1; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/book@ll" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/book@am.tf">book@ll</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ book name in amharic (ኣማርኛ)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/chapter" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ chapter number (1; 2; 3; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/code" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/code.tf">code</a>
# </div>
# <div class="fmono">int</div>
#
# <span> ✅ identifier of a clause atom relationship (0; 74; 367; ...)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://etcbc.github.io/bhsa/features/det" title="~/text-fabric-data/github/etcbc/bhsa/tf/2021/det.tf">det</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ✅ determinedne
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>

# %% [markdown]
# ## War as Worship
# ### Data-gathering
# #### Pred + Objc

# %%
FormsOfKillingPredObjc='''
clause
    phrase function=Pred
        word lex=HRG[|MWT[|QVL[|VBX[|CXV[ lex_utf8 bol_dict_EN bol_dict_HebArm
    phrase function=Objc
        word lex lex_utf8 sp=subs|nmpr bol_dict_EN bol_dict_HebArm
'''
FormsOfKillingPredObjc  = OT.search(FormsOfKillingPredObjc)
OT.table(FormsOfKillingPredObjc, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   1.63s 295 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=4&amp;verse=23&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 4:23">Genesis 4:23</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">כִּ֣י </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">פִצְעִ֔י </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=20&amp;verse=4&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 20:4">Genesis 20:4</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">הֲ</span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">גֹ֥וי </span></span><span class="txtu hbo">גַּם־</span><span class="txtu hbo">צַדִּ֖יק </span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽג׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽג׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽג׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">גֹ֥וי </span></span><span class="txtu hbo">גַּם־</span><span class="txtu hbo">צַדִּ֖יק </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">גֹ֥וי </span></span></span></td></tr></table>

# %%
OT.export(FormsOfKillingPredObjc, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='FormsOfKillingPredObjc.tsv')

# %%
FormsOfKillingPredObjc=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/FormsOfKillingPredObjc.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
FormsOfKillingPredObjc.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1                                  TEXT1  \
# 0  1  Genesis   4  23  427970  clause  כִּ֣י אִ֤ישׁ הָרַ֨גְתִּי֙ לְפִצְעִ֔י
# 1  2  Genesis  20   4  429301  clause      הֲגֹ֥וי גַּם־צַדִּ֖יק תַּהֲרֹֽג׃
# 2  3  Genesis  22  10  429540  clause                לִשְׁחֹ֖ט אֶת־בְּנֹֽו׃
# 3  4  Genesis  27  41  430427  clause    וְאַֽהַרְגָ֖ה אֶת־יַעֲקֹ֥ב אָחִֽי׃
# 4  5  Genesis  27  41  430427  clause    וְאַֽהַרְגָ֖ה אֶת־יַעֲקֹ֥ב אָחִֽי׃
#
#     NODE2   TYPE2          TEXT2 function2  NODE3 TYPE3          TEXT3  \
# 0  652804  phrase  הָרַ֨גְתִּי֙       Pred   2060  word  הָרַ֨גְתִּי֙
# 1  656934  phrase    תַּהֲרֹֽג׃       Pred   9317  word    תַּהֲרֹֽג׃
# 2  657689  phrase     לִשְׁחֹ֖ט       Pred  10467  word       שְׁחֹ֖ט
# 3  660252  phrase   אַֽהַרְגָ֖ה       Pred  14392  word   אַֽהַרְגָ֖ה
# 4  660252  phrase   אַֽהַרְגָ֖ה       Pred  14392  word   אַֽהַרְגָ֖ה
#
#                                         bol_dict_EN3 bol_dict_HebArm3  lex3  \
# 0  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 1  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 2          qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
# 3  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 4  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
#
#   lex_utf83   NODE4   TYPE4                  TEXT4 function4  NODE5 TYPE5  \
# 0       הרג  652803  phrase                אִ֤ישׁ       Objc   2059  word
# 1       הרג  656933  phrase   גֹ֥וי גַּם־צַדִּ֖יק       Objc   9314  word
# 2      שׁחט  657690  phrase          אֶת־בְּנֹֽו׃       Objc  10469  word
# 3       הרג  660253  phrase  אֶת־יַעֲקֹ֥ב אָחִֽי׃       Objc  14394  word
# 4       הרג  660253  phrase  אֶת־יַעֲקֹ֥ב אָחִֽי׃       Objc  14395  word
#
#        TEXT5                          bol_dict_EN5 bol_dict_HebArm5   lex5  \
# 0    אִ֤ישׁ   man; human being; somebody; each one           אִישׁ    >JC/
# 1     גֹ֥וי                         people, nation           גֹּוי    GWJ/
# 2  בְּנֹֽו׃                                    son           בֵּן I    BN/
# 3  יַעֲקֹ֥ב                                  Jacob         יַעֲקֹב   J<QB/
# 4   אָחִֽי׃                                brother            אָח I    >X/
#
#   lex_utf85   sp5
# 0      אישׁ  subs
# 1       גוי  subs
# 2        בן  subs
# 3      יעקב  nmpr
# 4        אח  subs

# %%
FormsOfKillingPredObjc.lex3.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ##### HRG[
# This is the default word used for homicide. and appears a total of 151 (Pred+Objc) + 42 (PreO) in the TNK with the vast majority of objects referring to sons, men, brother, king, prophet, warrior, 1000s, 100s, women, priest.
# WHile one can also HRG[ animals, this is the exception (1x BQR/ in Isa 22:13, BHMH/ 3x). Only two animal words appear in the 193 cases: BQR/, BHMH/. There where BHMH/ appears as object (3x)  it is always related to homicide. So is BHMH/ mentioned as the last element of an object phrase (all the firstborn in the land of Egypt, from human beings and until the firstborn of the cattle. Ex 13:15, also Lev 20:15-16).

# %%
HRGPredObjc='''
clause
    phrase function=Pred
        word lex=HRG[ lex_utf8 bol_dict_EN
    phrase function=Objc
        word lex lex_utf8 sp=subs|nmpr bol_dict_EN
'''
HRGPredObjc  = OT.search(HRGPredObjc)
OT.table(HRGPredObjc, start=1, end=1, condensed=False, colorMap={2: 'magenta'})
# Out:
#   1.29s 151 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=4&amp;verse=23&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 4:23">Genesis 4:23</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">כִּ֣י </span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">פִצְעִ֔י </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הָרַ֨גְתִּי֙ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">אִ֤ישׁ </span></span></span></td></tr></table>

# %%
HRGPredObjc='''
clause
    phrase function=PreO
        word lex=HRG[ lex_utf8 bol_dict_EN

'''
HRGPredObjc  = OT.search(HRGPredObjc)
OT.table(HRGPredObjc, start=1, end=1, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.45s 42 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=4&amp;verse=8&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 4:8">Genesis 4:8</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וַ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></td></tr></table>

# %%
HRGPredObjc='''
clause
    phrase function=Pred
        word lex=HRG[ lex_utf8 bol_dict_EN
    phrase function=Objc
        word lex=BHMH/|BQR/ lex_utf8 sp=subs|nmpr bol_dict_EN
'''
HRGPredObjc  = OT.search(HRGPredObjc)
OT.table(HRGPredObjc, start=1, end=100, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.91s 4 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Exodus&amp;chapter=13&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Exodus 13:15">Exodus 13:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וַ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהֲרֹ֨ג </span></span></span><span class="txtu hbo">יְהֹוָ֤ה </span><span class="plain rtl  hlbx" ><span class="txtu hbo">כָּל־</span><span class="txtu hbo">בְּכֹור֙ </span><span class="txtu hbo">בְּ</span><span class="txtu hbo">אֶ֣רֶץ </span><span class="txtu hbo">מִצְרַ֔יִם </span><span class="txtu hbo">מִ</span><span class="txtu hbo">בְּכֹ֥ר </span><span class="txtu hbo">אָדָ֖ם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">בְּכֹ֣ור </span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהֲרֹ֨ג </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יַּהֲרֹ֨ג </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">כָּל־</span><span class="txtu hbo">בְּכֹור֙ </span><span class="txtu hbo">בְּ</span><span class="txtu hbo">אֶ֣רֶץ </span><span class="txtu hbo">מִצְרַ֔יִם </span><span class="txtu hbo">מִ</span><span class="txtu hbo">בְּכֹ֥ר </span><span class="txtu hbo">אָדָ֖ם </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">בְּכֹ֣ור </span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=20&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Leviticus 20:15">Leviticus 20:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֖ה </span></span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽגוּ׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽגוּ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">תַּהֲרֹֽגוּ׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֖ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֖ה </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=20&amp;verse=16&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Leviticus 20:16">Leviticus 20:16</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַגְתָּ֥ </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הָ</span><span class="txtu hbo">אִשָּׁ֖ה </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרַגְתָּ֥ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הָרַגְתָּ֥ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הָ</span><span class="txtu hbo">אִשָּׁ֖ה </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֶת־</span><span class="txtu hbo">הַ</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּהֵמָ֑ה </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Jesaia&amp;chapter=22&amp;verse=13&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Isaiah 22:13">Isaiah 22:13</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרֹ֤ג׀ </span></span></span><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּקָר֙ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הָרֹ֤ג׀ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הָרֹ֤ג׀ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hl" ><span class="txtu hbo">בָּקָר֙ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בָּקָר֙ </span></span></span></td></tr></table>

# %%
HRGPredObjc=(FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=="HRG["])
HRGPredObjc.head(5)
# Out:
#    R       S1  S2  S3   NODE1   TYPE1                                  TEXT1  \
# 0  1  Genesis   4  23  427970  clause  כִּ֣י אִ֤ישׁ הָרַ֨גְתִּי֙ לְפִצְעִ֔י
# 1  2  Genesis  20   4  429301  clause      הֲגֹ֥וי גַּם־צַדִּ֖יק תַּהֲרֹֽג׃
# 3  4  Genesis  27  41  430427  clause    וְאַֽהַרְגָ֖ה אֶת־יַעֲקֹ֥ב אָחִֽי׃
# 4  5  Genesis  27  41  430427  clause    וְאַֽהַרְגָ֖ה אֶת־יַעֲקֹ֥ב אָחִֽי׃
# 5  6  Genesis  34  25  431411  clause           וַיַּֽהַרְג֖וּ כָּל־זָכָֽר׃
#
#     NODE2   TYPE2          TEXT2 function2  NODE3 TYPE3          TEXT3  \
# 0  652804  phrase  הָרַ֨גְתִּי֙       Pred   2060  word  הָרַ֨גְתִּי֙
# 1  656934  phrase    תַּהֲרֹֽג׃       Pred   9317  word    תַּהֲרֹֽג׃
# 3  660252  phrase   אַֽהַרְגָ֖ה       Pred  14392  word   אַֽהַרְגָ֖ה
# 4  660252  phrase   אַֽהַרְגָ֖ה       Pred  14392  word   אַֽהַרְגָ֖ה
# 5  663248  phrase  יַּֽהַרְג֖וּ       Pred  18923  word  יַּֽהַרְג֖וּ
#
#                                         bol_dict_EN3 bol_dict_HebArm3  lex3  \
# 0  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 1  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 3  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 4  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 5  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
#
#   lex_utf83   NODE4   TYPE4                  TEXT4 function4  NODE5 TYPE5  \
# 0       הרג  652803  phrase                אִ֤ישׁ       Objc   2059  word
# 1       הרג  656933  phrase   גֹ֥וי גַּם־צַדִּ֖יק       Objc   9314  word
# 3       הרג  660253  phrase  אֶת־יַעֲקֹ֥ב אָחִֽי׃       Objc  14394  word
# 4       הרג  660253  phrase  אֶת־יַעֲקֹ֥ב אָחִֽי׃       Objc  14395  word
# 5       הרג  663249  phrase          כָּל־זָכָֽר׃       Objc  18924  word
#
#        TEXT5                          bol_dict_EN5 bol_dict_HebArm5   lex5  \
# 0    אִ֤ישׁ   man; human being; somebody; each one           אִישׁ    >JC/
# 1     גֹ֥וי                         people, nation           גֹּוי    GWJ/
# 3  יַעֲקֹ֥ב                                  Jacob         יַעֲקֹב   J<QB/
# 4   אָחִֽי׃                                brother            אָח I    >X/
# 5      כָּל־                            all, every            כֹּל     KL/
#
#   lex_utf85   sp5
# 0      אישׁ  subs
# 1       גוי  subs
# 3      יעקב  nmpr
# 4        אח  subs
# 5        כל  subs

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
HRGPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
HRGPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### MWT[
# The standard word for dying of human beings is MWT. In the hifil stem it becomes a synonym for HRG[ and is used to perform homocide (e.g. Gen 42:37). The standard objects are son, man, people, David, women, king, etc.
#
# Like HRG[, one can also MWT[ animals. This is, however, an exception. Only 5 animals appear in the list of objects (donkey, camel, lmb, bull, fish). However, like with HRG[+BHMH/ the animals appear at the end of an object phrase that has human beings at the head of the phrase. Thus, they appear in the context of homicide (1 Sam 15:3) with Psa 105:28 as an exception.

# %%
MWTPredObjc=(FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=="MWT["])
MWTPredObjc.head(5)
# Out:
#      R       S1  S2  S3   NODE1   TYPE1  \
# 12  13  Genesis  42  37  432524  clause
# 13  14  Genesis  42  37  432524  clause
# 26  27   Exodus  16   3  435253  clause
# 27  28   Exodus  16   3  435253  clause
# 28  29   Exodus  17   3  435427  clause
#
#                                                 TEXT1   NODE2   TYPE2  \
# 12                       אֶת־שְׁנֵ֤י בָנַי֙ תָּמִ֔ית   666548  phrase
# 13                       אֶת־שְׁנֵ֤י בָנַי֙ תָּמִ֔ית   666548  phrase
# 26  לְהָמִ֛ית אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה בָּרָעָֽב...  674740  phrase
# 27  לְהָמִ֛ית אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה בָּרָעָֽב...  674740  phrase
# 28  לְהָמִ֥ית אֹתִ֛י וְאֶת־בָּנַ֥י וְאֶת־מִקְנַ֖י ...  675239  phrase
#
#          TEXT2 function2  NODE3 TYPE3      TEXT3  \
# 12   תָּמִ֔ית       Pred  24097  word  תָּמִ֔ית
# 13   תָּמִ֔ית       Pred  24097  word  תָּמִ֔ית
# 26  לְהָמִ֛ית       Pred  37429  word   הָמִ֛ית
# 27  לְהָמִ֛ית       Pred  37429  word   הָמִ֛ית
# 28  לְהָמִ֥ית       Pred  38195  word   הָמִ֥ית
#
#                                          bol_dict_EN3 bol_dict_HebArm3  lex3  \
# 12  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 13  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 26  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 27  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 28  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
#
#    lex_utf83   NODE4   TYPE4                                 TEXT4 function4  \
# 12       מות  666547  phrase                   אֶת־שְׁנֵ֤י בָנַי֙       Objc
# 13       מות  666547  phrase                   אֶת־שְׁנֵ֤י בָנַי֙       Objc
# 26       מות  674741  phrase           אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה       Objc
# 27       מות  674741  phrase           אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה       Objc
# 28       מות  675240  phrase  אֹתִ֛י וְאֶת־בָּנַ֥י וְאֶת־מִקְנַ֖י       Objc
#
#     NODE5 TYPE5     TEXT5            bol_dict_EN5 bol_dict_HebArm5   lex5  \
# 12  24095  word  שְׁנֵ֤י                      two        שְׁנַיִם   CNJM/
# 13  24096  word   בָנַי֙                      son           בֵּן I    BN/
# 26  37431  word     כָּל־              all, every            כֹּל     KL/
# 27  37433  word  קָּהָ֥ל   assembly, congregation           קָהָל    QHL/
# 28  38199  word  בָּנַ֥י                      son           בֵּן I    BN/
#
#    lex_utf85   sp5
# 12     שׁנים  subs
# 13        בן  subs
# 26        כל  subs
# 27       קהל  subs
# 28        בן  subs

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
MWTPredObjcTF='''
clause
    phrase function=Pred
        word lex=MWT[ vs=hif lex_utf8 bol_dict_EN
    phrase function=Objc
        word lex=XMWR/|GML/|FH/|CWR/|DGH/ lex_utf8 sp=subs|nmpr bol_dict_EN
'''
MWTPredObjcTF  = OT.search(MWTPredObjcTF)
OT.table(MWTPredObjcTF, start=1, end=5, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.94s 5 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Samuel_I&amp;chapter=15&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="1_Samuel 15:3">1_Samuel 15:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="plain rtl  hl" ><span class="txtu hbo">שֹּׁ֣ור </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">שֶׂ֔ה </span><span class="txtu hbo">מִ</span><span class="txtu hbo">גָּמָ֖ל </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">חֲמֹֽור׃ ס </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="plain rtl  hl" ><span class="txtu hbo">שֹּׁ֣ור </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">שֶׂ֔ה </span><span class="txtu hbo">מִ</span><span class="txtu hbo">גָּמָ֖ל </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">חֲמֹֽור׃ ס </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שֹּׁ֣ור </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Samuel_I&amp;chapter=15&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="1_Samuel 15:3">1_Samuel 15:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="txtu hbo">שֹּׁ֣ור </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="plain rtl  hl" ><span class="txtu hbo">שֶׂ֔ה </span></span><span class="txtu hbo">מִ</span><span class="txtu hbo">גָּמָ֖ל </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">חֲמֹֽור׃ ס </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="txtu hbo">שֹּׁ֣ור </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="plain rtl  hl" ><span class="txtu hbo">שֶׂ֔ה </span></span><span class="txtu hbo">מִ</span><span class="txtu hbo">גָּמָ֖ל </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">חֲמֹֽור׃ ס </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שֶׂ֔ה </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Samuel_I&amp;chapter=15&amp;verse=3&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="1_Samuel 15:3">1_Samuel 15:3</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="txtu hbo">שֹּׁ֣ור </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">שֶׂ֔ה </span><span class="txtu hbo">מִ</span><span class="plain rtl  hl" ><span class="txtu hbo">גָּמָ֖ל </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">חֲמֹֽור׃ ס </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">הֵמַתָּ֞ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">מֵ</span><span class="txtu hbo">אִ֣ישׁ </span><span class="txtu hbo">עַד־</span><span class="txtu hbo">אִשָּׁ֗ה </span><span class="txtu hbo">מֵֽ</span><span class="txtu hbo">עֹלֵל֙ </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">יֹונֵ֔ק </span><span class="txtu hbo">מִ</span><span class="txtu hbo">שֹּׁ֣ור </span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span class="txtu hbo">שֶׂ֔ה </span><span class="txtu hbo">מִ</span><span class="plain rtl  hl" ><span class="txtu hbo">גָּמָ֖ל </span></span><span class="txtu hbo">וְ</span><span class="txtu hbo">עַד־</span><span

# %% [markdown]
# ##### QVL[

# %%
QVLPredObjc=(FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=="QVL["])
QVLPredObjc.head(5)
# Out:
# Empty DataFrame
# Columns: [R, S1, S2, S3, NODE1, TYPE1, TEXT1, NODE2, TYPE2, TEXT2, function2, NODE3, TYPE3, TEXT3, bol_dict_EN3, bol_dict_HebArm3, lex3, lex_utf83, NODE4, TYPE4, TEXT4, function4, NODE5, TYPE5, TEXT5, bol_dict_EN5, bol_dict_HebArm5, lex5, lex_utf85, sp5]
# Index: []

# %% [markdown]
# ##### VBX[
# - WIth the noun טֶ֨בַח֙ it means: slaugher for food (Gen 43:16).
# - Eze 21:15: used for killing of human beings (טֶ֨בַח֙).
# - Psa 37:14 killing of human beings.
# - Prov 9:2 slauther for food (טֶ֨בַח֙)!

# %%
VBXPredObjc=(FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=="VBX["])
VBXPredObjc.head(5)
# Out:
#        R        S1  S2  S3   NODE1   TYPE1                           TEXT1  \
# 14    15   Genesis  43  16  432610  clause              וּטְבֹ֤חַ טֶ֨בַח֙
# 208  209   Ezekiel  21  15  482307  clause       לְמַ֨עַן טְבֹ֤חַ טֶ֨בַח֙
# 229  230    Psalms  37  14  491921  clause  לִ֝טְבֹ֗וחַ יִשְׁרֵי־דָֽרֶךְ׃
# 236  237  Proverbs   9   2  501057  clause             טָבְחָ֣ה טִ֭בְחָהּ
#
#       NODE2   TYPE2              TEXT2 function2   NODE3 TYPE3      TEXT3  \
# 14   666808  phrase           טְבֹ֤חַ       Pred   24458  word   טְבֹ֤חַ
# 208  813310  phrase  לְמַ֨עַן טְבֹ֤חַ       Pred  274767  word   טְבֹ֤חַ
# 229  839433  phrase       לִ֝טְבֹ֗וחַ       Pred  316367  word  טְבֹ֗וחַ
# 236  862943  phrase          טָבְחָ֣ה       Pred  349187  word  טָבְחָ֣ה
#
#               bol_dict_EN3 bol_dict_HebArm3  lex3 lex_utf83   NODE4   TYPE4  \
# 14   qal: slaughter, kill;             טבח   VBX[       טבח  666809  phrase
# 208  qal: slaughter, kill;             טבח   VBX[       טבח  813311  phrase
# 229  qal: slaughter, kill;             טבח   VBX[       טבח  839434  phrase
# 236  qal: slaughter, kill;             טבח   VBX[       טבח  862944  phrase
#
#                   TEXT4 function4   NODE5 TYPE5       TEXT5  \
# 14             טֶ֨בַח֙       Objc   24459  word    טֶ֨בַח֙
# 208            טֶ֨בַח֙       Objc  274768  word    טֶ֨בַח֙
# 229  יִשְׁרֵי־דָֽרֶךְ׃       Objc  316369  word   דָֽרֶךְ׃
# 236          טִ֭בְחָהּ       Objc  349188  word  טִ֭בְחָהּ
#
#                          bol_dict_EN5 bol_dict_HebArm5  lex5 lex_utf85   sp5
# 14                       slaughtering          טֶבַח I  VBX/       טבח  subs
# 208                      slaughtering          טֶבַח I  VBX/       טבח  subs
# 229  way, road, journey; custom (ext)         דֶּרֶךְ   DRK/       דרך  subs
# 236                      slaughtering          טֶבַח I  VBX/       טבח  subs

# %%
figure(num=None, figsize=(5, 2), dpi=80, facecolor='w', edgecolor='k')
VBXPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()
figure(num=None, figsize=(5, 2), dpi=80, facecolor='w', edgecolor='k')
VBXPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### CXV[

# %%
CXVPredObjc=(FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=="CXV["])
CXVPredObjc.head(5)
# Out:
#      R       S1  S2  S3   NODE1   TYPE1  \
# 2    3  Genesis  22  10  429540  clause
# 10  11  Genesis  37  31  431786  clause
# 11  12  Genesis  37  31  431786  clause
# 17  18   Exodus  12  21  434815  clause
# 32  33   Exodus  29  11  436602  clause
#
#                                                 TEXT1   NODE2   TYPE2  \
# 2                             לִשְׁחֹ֖ט אֶת־בְּנֹֽו׃   657689  phrase
# 10                 וַֽיִּשְׁחֲטוּ֙ שְׂעִ֣יר עִזִּ֔ים   664348  phrase
# 11                 וַֽיִּשְׁחֲטוּ֙ שְׂעִ֣יר עִזִּ֔ים   664348  phrase
# 17                            וְשַׁחֲט֥וּ הַפָּֽסַח׃   673413  phrase
# 32  וְשָׁחַטְתָּ֥ אֶת־הַפָּ֖ר לִפְנֵ֣י יְהוָ֑ה פֶּ...  678958  phrase
#
#             TEXT2 function2  NODE3 TYPE3          TEXT3  \
# 2      לִשְׁחֹ֖ט       Pred  10467  word       שְׁחֹ֖ט
# 10  יִּשְׁחֲטוּ֙       Pred  20747  word  יִּשְׁחֲטוּ֙
# 11  יִּשְׁחֲטוּ֙       Pred  20747  word  יִּשְׁחֲטוּ֙
# 17     שַׁחֲט֥וּ       Pred  35166  word     שַׁחֲט֥וּ
# 32   שָׁחַטְתָּ֥       Pred  44735  word   שָׁחַטְתָּ֥
#
#                                  bol_dict_EN3 bol_dict_HebArm3  lex3  \
# 2   qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
# 10  qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
# 11  qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
# 17  qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
# 32  qal: slaughter, kill; ni: be slaughtered;           שׁחט I  CXV[
#
#    lex_utf83   NODE4   TYPE4               TEXT4 function4  NODE5 TYPE5  \
# 2       שׁחט  657690  phrase       אֶת־בְּנֹֽו׃       Objc  10469  word
# 10      שׁחט  664349  phrase  שְׂעִ֣יר עִזִּ֔ים       Objc  20748  word
# 11      שׁחט  664349  phrase  שְׂעִ֣יר עִזִּ֔ים       Objc  20749  word
# 17      שׁחט  673414  phrase         הַפָּֽסַח׃       Objc  35168  word
# 32      שׁחט  678959  phrase        אֶת־הַפָּ֖ר       Objc  44738  word
#
#         TEXT5                    bol_dict_EN5 bol_dict_HebArm5   lex5  \
# 2   בְּנֹֽו׃                              son           בֵּן I    BN/
# 10  שְׂעִ֣יר         he-goat (n); hairy (adj)        שָׂעִיר I  F<JR/
# 11  עִזִּ֔ים                   goat; goathair          עֵז III  <Z==/
# 17  פָּֽסַח׃   Passover (festival, sacrifice)         פֶּסַח I   PSX/
# 32     פָּ֖ר                       young bull            פַּר     PR/
#
#    lex_utf85   sp5
# 2         בן  subs
# 10     שׂעיר  subs
# 11        עז  subs
# 17       פסח  subs
# 32        פר  subs

# %%
FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=='CXV['].bol_dict_EN5.value_counts(sort=False).sort_values(ascending=False)
# Out:
# burnt offering                          9
# son                                     7
# Passover (festival, sacrifice)          6
# sin, sin-offering, expiation            6
# young bull                              5
# ram; leader of a nation                 4
# young ram                               4
# sacrifice                               3
# cattle, cows (collective), herd(s)      3
# guilt, wrong; guilt offering            3
# Zedekiah                                3
# one, once                               2
# Judah                                   2
# all, every                              2
# flock                                   2
# bull(ock), steer                        2
# bird; birds                             2
# he-goat (n); hairy (adj)                2
# goat; goathair                          2
# final offering, peace offering          1
# seven                                   1
# man; human being; somebody; each one    1
# (bull-) calf                            1
# blood                                   1
# noble                                   1
# official, leader, prince                1
# Name: bol_dict_EN5, dtype: int64

# %%
FormsOfKillingPredObjc[FormsOfKillingPredObjc['lex3']=='CXV['].bol_dict_HebArm5.value_counts(sort=False).sort_values(ascending=False)
# Out:
# עֹלָה I          9
# בֵּן I           7
# פֶּסַח I         6
# חַטָּאת          6
# פַּר             5
# אַיִל II         4
# זֶבַח I          3
# בָּקָר I         3
# אָשָׁם I         3
# צִדְקִיָּהוּ     3
# כֶּבֶשׂ          3
# אֶחָד            2
# יְהוּדָה         2
# כֹּל             2
# צֹאן             2
# שֹׁור I          2
# צִפֹּור I        2
# שָׂעִיר I        2
# עֵז III          2
# שֶׁלֶם I         1
# כֶּשֶׂב          1
# שֶׁבַע I         1
# אִישׁ            1
# עֵגֶל I          1
# דָּם             1
# חֹר II           1
# שַׂר             1
# Name: bol_dict_HebArm5, dtype: int64

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
CXVPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
CXVPredObjc.bol_dict_HebArm5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
CXVPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# - Gen 22:10 Akeda
# - Lev 1:5/22:28/ "son of the cattle" - clear cultic context - Eze 16:21 human sacrifice (slaughering of children, like the sons of bulls)
# - Only Jeremiah and 2 Kgs know of the slaughering of the sons

# %%
CXVPredObjc='''
clause
    phrase function=Pred
        word lex=CXV[ lex_utf8
    phrase function=Objc
        word lex=YDQJHW/|JHWDH/|BN/ lex_utf8
'''
CXVPredObjc  = OT.search(CXVPredObjc)
OT.table(CXVPredObjc, start=1, end=20, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.68s 12 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=22&amp;verse=10&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 22:10">Genesis 22:10</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">לִ</span><span class="plain rtl  hl" ><span class="txtu hbo">שְׁחֹ֖ט </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹֽו׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="txtu hbo">לִ</span><span class="plain rtl  hl" ><span class="txtu hbo">שְׁחֹ֖ט </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שְׁחֹ֖ט </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹֽו׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹֽו׃ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=1&amp;verse=5&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Leviticus 1:5">Leviticus 1:5</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחַ֛ט </span></span></span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בֶּ֥ן </span></span><span class="txtu hbo">הַ</span><span class="txtu hbo">בָּקָ֖ר </span></span><span class="txtu hbo">לִ</span><span class="txtu hbo">פְנֵ֣י </span><span class="txtu hbo">יְהוָ֑ה </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחַ֛ט </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחַ֛ט </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בֶּ֥ן </span></span><span class="txtu hbo">הַ</span><span class="txtu hbo">בָּקָ֖ר </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בֶּ֥ן </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">3</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Leviticus&amp;chapter=22&amp;verse=28&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Leviticus 22:28">Leviticus 22:28</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="plain rtl  hlbx" ><span class="txtu hbo">אֹתֹ֣ו </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֔ו </span></span></span><span class="txtu hbo">לֹ֥א </span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תִשְׁחֲט֖וּ </span></span></span><span class="txtu hbo">בְּ</span><span class="txtu hbo">יֹ֥ום </span><span class="txtu hbo">אֶחָֽד׃ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">תִשְׁחֲט֖וּ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">תִשְׁחֲט֖וּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֹתֹ֣ו </span><span class="txtu hbo">וְ</span><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֔ו </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֹ֔ו </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">4</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=25&amp;verse=7&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 25:7">2_Kings 25:7</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֵי֙ </span></span><span class="txtu hbo">צִדְקִיָּ֔הוּ </span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחֲט֖וּ </span></span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">עֵינָ֑יו </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחֲט֖וּ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחֲט֖וּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֵי֙ </span></span><span class="txtu hbo">צִדְקִיָּ֔הוּ </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">בְּנֵי֙ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">5</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Reges_II&amp;chapter=25&amp;verse=7&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="2_Kings 25:7">2_Kings 25:7</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וְ</span><span class="plain rtl  hlbx" ><span class="txtu hbo">אֶת־</span><span class="txtu hbo">בְּנֵי֙ </span><span class="plain rtl  hl" ><span class="txtu hbo">צִדְקִיָּ֔הוּ </span></span></span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחֲט֖וּ </span></span></span><span class="txtu hbo">לְ</span><span class="txtu hbo">עֵינָ֑יו </span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">שָׁחֲט֖וּ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hb

# %%
FormsOfKilling='''
word lex=QVL[ lex_utf8

'''
FormsOfKilling  = OT.search(FormsOfKilling)
OT.table(FormsOfKilling, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.21s 10 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Psalmi&amp;chapter=139&amp;verse=19&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Psalms 139:19">Psalms 139:19</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">תִּקְטֹ֖ל </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Iob&amp;chapter=13&amp;verse=15&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Job 13:15">Job 13:15</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יִ֭קְטְלֵנִי </span></span></span></td></tr></table>

# %% [markdown]
# #### Pred + ObjcSuffix

# %%
FormsOfKillingPreO='''
clause
    phrase function=PreO
        word lex=HRG[|MWT[|QVL[|VBX[|CXV[ lex_utf8 prs
'''
FormsOfKillingPreO  = OT.search(FormsOfKillingPreO)
OT.table(FormsOfKillingPreO, start=1, end=2, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.35s 128 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">clause</th><th class="tf">phrase</th><th class="tf">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=4&amp;verse=8&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 4:8">Genesis 4:8</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx" ><span class="txtu hbo">וַ</span><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יַּהַרְגֵֽהוּ׃ </span></span></span></td></tr>
# <tr class="tf rtl"><td class="tf rtl">2</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=4&amp;verse=14&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 4:14">Genesis 4:14</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl l hlbx" ><span class="txtu hbo">כָל־</span></span><span class="plain rtl r hlbx" ><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַֽהַרְגֵֽנִי׃ </span></span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hlbx"  style="border-color: magenta;" ><span class="plain rtl  hl" ><span class="txtu hbo">יַֽהַרְגֵֽנִי׃ </span></span></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">יַֽהַרְגֵֽנִי׃ </span></span></span></td></tr></table>

# %%
OT.export(FormsOfKillingPreO, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='FormsOfKillingPreO.tsv')

# %%
FormsOfKillingPreO=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/FormsOfKillingPreO.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
FormsOfKillingPreO.head()
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   4   8  427913  clause
# 1  2  Genesis   4  14  427937  clause
# 2  3  Genesis   4  25  427978  clause
# 3  4  Genesis  20  11  429340  clause
# 4  5  Genesis  26   7  430106  clause
#
#                                                TEXT1   NODE2   TYPE2  \
# 0                                  וַיַּהַרְגֵֽהוּ׃   652635  phrase
# 1                                כָל־יַֽהַרְגֵֽנִי׃   652703  phrase
# 2                            כִּ֥י הֲרָגֹ֖ו קָֽיִן׃   652835  phrase
# 3             וַהֲרָג֖וּנִי עַל־דְּבַ֥ר אִשְׁתִּֽי׃   657053  phrase
# 4  פֶּן־יַֽהַרְגֻ֜נִי אַנְשֵׁ֤י הַמָּקֹום֙ עַל־רִ...  659326  phrase
#
#              TEXT2 function2  NODE3 TYPE3            TEXT3  lex3 lex_utf83  \
# 0  יַּהַרְגֵֽהוּ׃       PreO   1807  word  יַּהַרְגֵֽהוּ׃   HRG[       הרג
# 1  יַֽהַרְגֵֽנִי׃       PreO   1906  word  יַֽהַרְגֵֽנִי׃   HRG[       הרג
# 2        הֲרָגֹ֖ו       PreO   2099  word        הֲרָגֹ֖ו   HRG[       הרג
# 3     הֲרָג֖וּנִי       PreO   9483  word     הֲרָג֖וּנִי   HRG[       הרג
# 4   יַֽהַרְגֻ֜נִי       PreO  13114  word   יַֽהַרְגֻ֜נִי   HRG[       הרג
#
#   prs3
# 0   HW
# 1   NJ
# 2    W
# 3   NJ
# 4   NJ

# %%
FormsOfKillingPreO.lex3.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %% [markdown]
# ##### HRG[

# %%
HRGPreO=(FormsOfKillingPreO[FormsOfKillingPreO['lex3']=="HRG["])
HRGPreO.head(5)
# Out:
#    R       S1  S2  S3   NODE1   TYPE1  \
# 0  1  Genesis   4   8  427913  clause
# 1  2  Genesis   4  14  427937  clause
# 2  3  Genesis   4  25  427978  clause
# 3  4  Genesis  20  11  429340  clause
# 4  5  Genesis  26   7  430106  clause
#
#                                                TEXT1   NODE2   TYPE2  \
# 0                                  וַיַּהַרְגֵֽהוּ׃   652635  phrase
# 1                                כָל־יַֽהַרְגֵֽנִי׃   652703  phrase
# 2                            כִּ֥י הֲרָגֹ֖ו קָֽיִן׃   652835  phrase
# 3             וַהֲרָג֖וּנִי עַל־דְּבַ֥ר אִשְׁתִּֽי׃   657053  phrase
# 4  פֶּן־יַֽהַרְגֻ֜נִי אַנְשֵׁ֤י הַמָּקֹום֙ עַל־רִ...  659326  phrase
#
#              TEXT2 function2  NODE3 TYPE3            TEXT3  lex3 lex_utf83  \
# 0  יַּהַרְגֵֽהוּ׃       PreO   1807  word  יַּהַרְגֵֽהוּ׃   HRG[       הרג
# 1  יַֽהַרְגֵֽנִי׃       PreO   1906  word  יַֽהַרְגֵֽנִי׃   HRG[       הרג
# 2        הֲרָגֹ֖ו       PreO   2099  word        הֲרָגֹ֖ו   HRG[       הרג
# 3     הֲרָג֖וּנִי       PreO   9483  word     הֲרָג֖וּנִי   HRG[       הרג
# 4   יַֽהַרְגֻ֜נִי       PreO  13114  word   יַֽהַרְגֻ֜נִי   HRG[       הרג
#
#   prs3
# 0   HW
# 1   NJ
# 2    W
# 3   NJ
# 4   NJ

# %%
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
HRGPreO.prs3.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### MWT[

# %%
MWTPreO=(FormsOfKillingPreO[FormsOfKillingPreO['lex3']=="MWT["])
MWTPreO.head(5)
# Out:
#      R       S1  S2  S3   NODE1   TYPE1                         TEXT1   NODE2  \
# 6    7  Genesis  37  18  431722  clause                 לַהֲמִיתֹֽו׃   664171
# 8    9  Genesis  38   7  431834  clause        וַיְמִתֵ֖הוּ יְהוָֽה׃   664491
# 10  11   Exodus   4  24  433970  clause                   הֲמִיתֹֽו׃   670796
# 18  19  Numbers  16  13  442704  clause  לַהֲמִיתֵ֖נוּ בַּמִּדְבָּ֑ר   697566
# 20  21  Numbers  35  19  444784  clause          ה֥וּא יְמִיתֶֽנּוּ׃   703896
#
#      TYPE2           TEXT2 function2  NODE3 TYPE3           TEXT3  lex3  \
# 6   phrase   לַהֲמִיתֹֽו׃       PreO  20507  word     הֲמִיתֹֽו׃   MWT[
# 8   phrase     יְמִתֵ֖הוּ       PreO  20941  word     יְמִתֵ֖הוּ   MWT[
# 10  phrase     הֲמִיתֹֽו׃       PreO  30684  word     הֲמִיתֹֽו׃   MWT[
# 18  phrase  לַהֲמִיתֵ֖נוּ       PreO  80300  word    הֲמִיתֵ֖נוּ   MWT[
# 20  phrase  יְמִיתֶֽנּוּ׃       PreO  92196  word  יְמִיתֶֽנּוּ׃   MWT[
#
#    lex_utf83 prs3
# 6        מות    W
# 8        מות   HW
# 10       מות    W
# 18       מות   NW
# 20       מות   HW

# %%
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
MWTPreO.prs3.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### QVL[
# Only object is a human being.

# %%
QVLPreO=(FormsOfKillingPreO[FormsOfKillingPreO['lex3']=="QVL["])
QVLPreO.head(5)
# Out:
#        R   S1  S2  S3   NODE1   TYPE1          TEXT1   NODE2   TYPE2  \
# 107  108  Job  13  15  498421  clause  יִ֭קְטְלֵנִי   855622  phrase
#
#              TEXT2 function2   NODE3 TYPE3          TEXT3  lex3 lex_utf83 prs3
# 107  יִ֭קְטְלֵנִי       PreO  339388  word  יִ֭קְטְלֵנִי   QVL[       קטל   NJ

# %%
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
QVLPreO.prs3.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### VBX[
#
# This one case deals with the slaughter of a cow as an illegal action. For what purpose the slaugther takes place is unclear.
#
# ![Screenshot 2022-11-14 at 12.47.50.png](attachment:7c70ae17-e67c-42df-b7e2-f3657341f7c1.png)

# %%
VBXPreO=(FormsOfKillingPreO[FormsOfKillingPreO['lex3']=="VBX["])
VBXPreO.head(5)
# Out:
#      R      S1  S2  S3   NODE1   TYPE1        TEXT1   NODE2   TYPE2  \
# 13  14  Exodus  21  37  435909  clause  וּטְבָחֹ֖ו   676752  phrase
#
#         TEXT2 function2  NODE3 TYPE3      TEXT3  lex3 lex_utf83 prs3
# 13  טְבָחֹ֖ו       PreO  40598  word  טְבָחֹ֖ו   VBX[       טבח    W

# %%
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
VBXPreO.prs3.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %% [markdown]
# ##### CXV[
# - cultic: Lev 3:2; 9:15; 2 Chr 29:24.
#
# - hyperbolic/metaphorical use: Num 14:16 (God slaughters his people). The parallel account in Deut 9:28 uses the word MWT[. Judg 12:6 (killing of Ephraimites who are not able to pronounce Shibollet). 1 Kgs 18:40 (Elija slaughters the Baal Prophets). 2 kgs 10:14 (Jehu slaughters the brothers of Ahasja). Jer 41:7 (Ishmael slaughters a group of mourning people).

# %%
CXVPreO=(FormsOfKillingPreO[FormsOfKillingPreO['lex3']=="CXV["])
CXVPreO.head(15)
# Out:
#        R            S1  S2  S3   NODE1   TYPE1  \
# 14    15     Leviticus   3   2  437989  clause
# 15    16     Leviticus   9  15  438660  clause
# 17    18       Numbers  14  16  442422  clause
# 30    31        Judges  12   6  452713  clause
# 77    78       1_Kings  18  40  463940  clause
# 80    81       2_Kings  10  14  466340  clause
# 96    97      Jeremiah  41   7  478498  clause
# 126  127  2_Chronicles  29  24  514893  clause
#
#                                                  TEXT1   NODE2   TYPE2  \
# 14                 וּשְׁחָטֹ֕ו פֶּ֖תַח אֹ֣הֶל מֹועֵ֑ד   683165  phrase
# 15                                   וַיִּשְׁחָטֵ֥הוּ   685250  phrase
# 17                      וַיִּשְׁחָטֵ֖ם בַּמִּדְבָּֽר׃   696711  phrase
# 30    וַיִּשְׁחָט֖וּהוּ אֶל־מַעְבְּרֹ֣ות הַיַּרְדֵּ֑ן   727854  phrase
# 77                              וַיִּשְׁחָטֵ֖ם שָֽׁם׃   761802  phrase
# 80   וַֽיִּשְׁחָט֞וּם אֶל־בֹּ֣ור בֵּֽית־עֵ֗קֶד אַרְ...  768520  phrase
# 96   וַיִּשְׁחָטֵ֞ם יִשְׁמָעֵ֤אל בֶּן־נְתַנְיָה֙ אֶ...  802579  phrase
# 126                     וַיִּשְׁחָטוּם֙ הַכֹּ֣הֲנִ֔ים   902312  phrase
#
#                 TEXT2 function2   NODE3 TYPE3             TEXT3  lex3  \
# 14         שְׁחָטֹ֕ו       PreO   53186  word        שְׁחָטֹ֕ו   CXV[
# 15    יִּשְׁחָטֵ֥הוּ       PreO   57188  word   יִּשְׁחָטֵ֥הוּ   CXV[
# 17      יִּשְׁחָטֵ֖ם       PreO   78761  word     יִּשְׁחָטֵ֖ם   CXV[
# 30   יִּשְׁחָט֖וּהוּ       PreO  135545  word  יִּשְׁחָט֖וּהוּ   CXV[
# 77      יִּשְׁחָטֵ֖ם       PreO  191266  word     יִּשְׁחָטֵ֖ם   CXV[
# 80     יִּשְׁחָט֞וּם       PreO  201468  word    יִּשְׁחָט֞וּם   CXV[
# 96      יִּשְׁחָטֵ֞ם       PreO  257479  word     יִּשְׁחָטֵ֞ם   CXV[
# 126    יִּשְׁחָטוּם֙       PreO  421518  word    יִּשְׁחָטוּם֙   CXV[
#
#     lex_utf83 prs3
# 14       שׁחט    W
# 15       שׁחט   HW
# 17       שׁחט    M
# 30       שׁחט   HW
# 77       שׁחט    M
# 80       שׁחט    M
# 96       שׁחט    M
# 126      שׁחט    M

# %%
figure(num=None, figsize=(5, 3), dpi=80, facecolor='w', edgecolor='k')
CXVPreO.prs3.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.bol_dict_EN5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

figure(num=None, figsize=(5, 15), dpi=80, facecolor='w', edgecolor='k')
MWTPredObjc.lex5.value_counts(sort=False).sort_values().plot.barh()
plt.show()

# %%
MWTPredObjc.head()
# Out:
#      R       S1  S2  S3   NODE1   TYPE1  \
# 12  13  Genesis  42  37  432524  clause
# 13  14  Genesis  42  37  432524  clause
# 26  27   Exodus  16   3  435253  clause
# 27  28   Exodus  16   3  435253  clause
# 28  29   Exodus  17   3  435427  clause
#
#                                                 TEXT1   NODE2   TYPE2  \
# 12                       אֶת־שְׁנֵ֤י בָנַי֙ תָּמִ֔ית   666548  phrase
# 13                       אֶת־שְׁנֵ֤י בָנַי֙ תָּמִ֔ית   666548  phrase
# 26  לְהָמִ֛ית אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה בָּרָעָֽב...  674740  phrase
# 27  לְהָמִ֛ית אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה בָּרָעָֽב...  674740  phrase
# 28  לְהָמִ֥ית אֹתִ֛י וְאֶת־בָּנַ֥י וְאֶת־מִקְנַ֖י ...  675239  phrase
#
#          TEXT2 function2  NODE3 TYPE3      TEXT3  \
# 12   תָּמִ֔ית       Pred  24097  word  תָּמִ֔ית
# 13   תָּמִ֔ית       Pred  24097  word  תָּמִ֔ית
# 26  לְהָמִ֛ית       Pred  37429  word   הָמִ֛ית
# 27  לְהָמִ֛ית       Pred  37429  word   הָמִ֛ית
# 28  לְהָמִ֥ית       Pred  38195  word   הָמִ֥ית
#
#                                          bol_dict_EN3 bol_dict_HebArm3  lex3  \
# 12  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 13  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 26  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 27  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
# 28  qal: die; pi: kill; hi: kill, put to death; ho...             מות   MWT[
#
#    lex_utf83   NODE4   TYPE4                                 TEXT4 function4  \
# 12       מות  666547  phrase                   אֶת־שְׁנֵ֤י בָנַי֙       Objc
# 13       מות  666547  phrase                   אֶת־שְׁנֵ֤י בָנַי֙       Objc
# 26       מות  674741  phrase           אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה       Objc
# 27       מות  674741  phrase           אֶת־כָּל־הַקָּהָ֥ל הַזֶּ֖ה       Objc
# 28       מות  675240  phrase  אֹתִ֛י וְאֶת־בָּנַ֥י וְאֶת־מִקְנַ֖י       Objc
#
#     NODE5 TYPE5     TEXT5            bol_dict_EN5 bol_dict_HebArm5   lex5  \
# 12  24095  word  שְׁנֵ֤י                      two        שְׁנַיִם   CNJM/
# 13  24096  word   בָנַי֙                      son           בֵּן I    BN/
# 26  37431  word     כָּל־              all, every            כֹּל     KL/
# 27  37433  word  קָּהָ֥ל   assembly, congregation           קָהָל    QHL/
# 28  38199  word  בָּנַ֥י                      son           בֵּן I    BN/
#
#    lex_utf85   sp5
# 12     שׁנים  subs
# 13        בן  subs
# 26        כל  subs
# 27       קהל  subs
# 28        בן  subs

# %% [markdown]
# #### Slaughter language bible books

# %%
JerSlaughterWords='''
word lex~^.*MWT.*|^.*HRG.*|^.*CXV.*|^.*VBX.* lex_utf8 bol_dict_EN vs bol_dict_HebArm
'''
JerSlaughterWords  = OT.search(JerSlaughterWords)
OT.table(JerSlaughterWords, start=1, end=1, condensed=False, colorMap={2: 'magenta'})
# Out:
#   0.52s 1465 results
# <table><tr class="tf rtl"><th class="tf rtl">n</th><th class="tf rtl">p</th><th class="tf rtl">word</th></tr>
# <tr class="tf rtl"><td class="tf rtl">1</td><td class="tf rtl"><span class="tfsechead rtl"><span class="ltr"><a target="_blank" href="https://shebanq.ancient-data.org/hebrew/text?book=Genesis&amp;chapter=1&amp;verse=26&amp;version=2021&amp;mr=m&amp;qw=q&amp;tp=txt_p&amp;tr=hb&amp;wget=v&amp;qget=v&amp;nget=vt" title="Show this on SHEBANQ" sec="Genesis 1:26">Genesis 1:26</a></span></span></td><td class="tf rtl"><span class="rtl ubd"><span class="plain rtl  hl" ><span class="txtu hbo">דְמוּתֵ֑נוּ </span></span></span></td></tr></table>

# %%
OT.export(JerSlaughterWords, toDir='/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah', toFile='JerSlaughterWords.tsv')

# %%
JerSlaughterWords=pd.read_csv('/Users/oliverglanz/Library/CloudStorage/OneDrive-AndrewsUniversity/1200_AUS-research/Fabric-TEXT/3-A13_BibleBook_OT_Jeremiah/JerSlaughterWords_manipulated.txt',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
JerSlaughterWords.head()
# Out:
#     R       S1  S2  S3  NODE1 TYPE1            TEXT1  \
# 0   7  Genesis   4   8   1807  word  יַּהַרְגֵֽהוּ׃
# 1   8  Genesis   4  14   1906  word  יַֽהַרְגֵֽנִי׃
# 2   9  Genesis   4  15   1913  word          הֹרֵ֣ג
# 3  10  Genesis   4  23   2060  word    הָרַ֨גְתִּי֙
# 4  11  Genesis   4  25   2099  word        הֲרָגֹ֖ו
#
#                                         bol_dict_EN1 bol_dict_HebArm1  lex1  \
# 0  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 1  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 2  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 3  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
# 4  qal: kill, slay; ni: be killed, slain; pu: be ...             הרג   HRG[
#
#   lex_utf81  vs1
# 0       הרג  qal
# 1       הרג  qal
# 2       הרג  qal
# 3       הרג  qal
# 4       הרג  qal

# %%
JerSlaughterWords.groupby(['bol_dict_HebArm1','S1']).count().sort_values(['lex_utf81'], ascending=True)
# Out:
#                                  R  S2  S3  NODE1  TYPE1  TEXT1  bol_dict_EN1  \
# bol_dict_HebArm1 S1
# הרג              Habakkuk        1   1   1      1      1      1             1
# טַבַּח           Daniel          1   1   1      1      1      1             1
# מַטְבֵּחַ        Isaiah          1   1   1      1      1      1             1
# טִבְחָה I        Jeremiah        1   1   1      1      1      1             1
# מָוֶת            Song_of_songs   1   1   1      1      1      1             1
# טִבְחָה I        Psalms          1   1   1      1      1      1             1
# מֹות             Ezra            1   1   1      1      1      1             1
# מָוֶת            Habakkuk        1   1   1      1      1      1             1
# מות              Esther          1   1   1      1      1      1             1
# טַבָּחָה II      1_Samuel        1   1   1      1      1      1             1
# טבח              1_Samuel        1   1   1      1      1      1             1
#                  Deuteronomy     1   1   1      1      1      1             1
#                  Exodus          1   1   1      1      1      1             1
# טֶבַח I          Genesis         1   1   1      1      1      1             1
# טבח              Ezekiel         1   1   1      1      1      1             1
#                  Genesis         1   1   1      1      1      1             1
# מָוֶת            Exodus          1   1   1      1      1      1             1
# טבח              Lamentations    1   1   1      1      1      1             1
# מָוֶת            Esther          1   1   1      1      1      1             1
# הֶרֶג            Esther          1   1   1      1      1      1             1
#                  Ezekiel         1   1   1      1      1      1             1
# מָוֶת            Lamentations    1   1   1      1      1      1             1
# הֶרֶג            Proverbs        1   1   1      1      1      1             1
# שׁחט I           Judges          1   1   1      1      1      1             1
# הרג              Zechariah       1   1   1      1      1      1             1
# מְמֹותִים        Jeremiah        1   1   1      1      1      1             1
# שׁחט I           Ezra            1   1   1      1      1      1             1
# טבח              Psalms          1   1   1      1      1      1             1
# שׁחט I           1_Kings         1   1   1      1      1      1             1
# שַׁחֲטָה         Hosea           1   1   1      1      1      1             1
# טבח              Proverbs        1   1   1      1      1      1             1
# הרג              Ecclesiastes    1   1   1      1      1      1             1
# מְמֹותִים        Ezekiel         1   1   1      1      1      1             1
# טִבְחָה I        1_Samuel        1   1   1      1      1      1             1
# תְּמוּתָה        Psalms          2   2   2      2      2      2             2
# מָוֶת            Hosea           2   2   2      2      2      2             2
# מְרֵמֹות         Ezra            2   2   2      2      2      2             2
# טַבָּח II        1_Samuel        2   2   2      2      2      2             2
# טֶבַח I          Proverbs        2   2   2      2      2      2             2
# הרג              Proverbs        2   2   2      2      2      2             2
# מָוֶת            1_Chronicles    2   2   2      2      2      2             2
# הֲרֵגָה          Zechariah       2   2   2      2      2      2             2
# מָוֶת            Ruth            2   2   2      2      2      2             2
# הֶרֶג            Isaiah          2   2   2      2      2      2             2
# הרג              Leviticus       2   2   2      2      2      2             2
#                  Job             2   2   2      2      2      2             2
# מות              Ezekiel         2   2   2      2      2      2             2
#                  Hosea           2   2   2      2      2      2             2
# הרג              Hosea           2   2   2      2      2      2             2
# טֶבַח I          Jeremiah        2   2   2      2      2      2             2
# שׁחט I           Genesis         2   2   2      2      2      2             2
# מות              Proverbs        2   2   2      2      2      2             2
# הרג              Deuteronomy     2   2   2      2      2      2             2
# שׁחט I           Isaiah          3   3   3      3      3      3             3
#                  2_Kings         3   3   3      3      3      3             3
# מָוֶת            Joshua          3   3   3      3      3      3             3
# מות              Job             3   3   3      3      3      3             3
#                  1_Chronicles    3   3   3      3      3      3             3
# מָוֶת            Jonah           3   3   3      3      3      3             3
#                  Leviticus       3   3   3      3      3      3             3
# מות              Joshua          3   3   3      3      3      3             3
#                  Isaiah          3   3   3      3      3      3             3
# הֲרֵגָה          Jeremiah        3   3   3      3      3      3             3
# מָוֶת            1_Kings         3   3   3      3      3      3             3
# הרג              1_Chronicles    3   3   3      3      3      3             3
# שׁחט I           Numbers         3   3   3      3      3      3             3
# טֶבַח I          Ezekiel         3   3   3      3      3      3             3
# טבח              Jeremiah        3   3   3      3      3      3             3
# הרג              Jeremiah        3   3   3      3      3      3             3
# מָוֶת            Judges          4   4   4      4      4      4             4
# טֶבַח I          Isaiah          4   4   4      4      4      4             4
# הרג              Joshua          4   4   4      4      4      4             4
#                  Amos            4   4   4      4      4      4             4
# שׁחט I           1_Samuel        4   4   4      4      4      4             4
# מְרֵמֹות         Nehemiah        4   4   4      4      4      4             4
# הרג              Lamentations    4   4   4      4      4      4             4
#                  Nehemiah        4   4   4      4      4      4             4
#                  2_Kings         5   5   5      5      5      5             5
# מות              Psalms          5   5   5      5      5      5             5
# מָוֶת            Ezekiel         5   5   5      5      5      5             5
# הרג              1_Samuel        5   5   5      5      5      5             5
# מות              Genesis         6   6   6      6      6      6             6
# שׁחט I           Exodus          6   6   6      6      6      6             6
#                  Ezekiel         6   6   6      6      6      6             6
#                  Jeremiah        6   6   6      6      6      6             6
# מָוֶת            1_Samuel        6   6   6      6      6      6             6
#                  2_Kings         6   6   6      6      6      6             6
# טַבָּח II        Genesis         6   6   6      6      6      6             6
# מָוֶת            Ecclesiastes    6   6   6      6      6      6             6
#                  Genesis         7   7   7      7      7      7             7
#                  2_Chronicles    7   7   7      7      7      7             7
# טַבָּח II        2_Kings         7   7   7      7      7      7             7
# מָוֶת            Isaiah          8   8   8      8      8      8             8
# הרג              2_Samuel        8   8   8      8      8      8             8
# מָוֶת            Job             8   8   8      8      8      8             8
# שׁחט I           2_Chronicles    8   8   8      8      8      8             8
# הרג              Isaiah          9   9   9      9      9      9             9
# מות              Judges          9   9   9      9      9      9             9
# הרג              Psalms          9   9   9      9      9      9             9
# מָוֶת            Deuteronomy     9   9   9      9      9      9             9
#                  2_Samuel        9   9   9      9      9      9             9
#                  Numbers         9   9   9      9      9      9             9
# הרג              Esther          9   9   9      9      9      9             9
#                  Ezekiel        10  10  10     10     10     10            10
#                  1_Kings        11  11  11     11     11     11            11
#                  Numbers        11  11  11     11     11     11            11
#                  Exodus         11  11  11     11     11     11            11
# מות              Deuteronomy    11  11  11     11     11     11            11
#                  2_Chronicles   12  12  12     12     12     12            12
# הרג              2_Chronicles   12  12  12     12     12     12            12
# מָוֶת            Jeremiah       13  13  13     13     13     13            13
# מות              Exodus         15  15  15     15     15     15            15
#                  Leviticus      16  16  16     16     16     16            16
#                  Numbers        16  16  16     16     16     16            16
# הרג              Genesis        16  16  16     16     16     16            16
#                  Judges         16  16  16     16     16     16            16
# מות              Jeremiah       17  17  17     17     17     17            17
# טַבָּח II        Jeremiah       17  17  17     17     17     17            17
# מָוֶת            Proverbs       19  19  19     19     19     19            19
# מות              1_Kings        19  19  19     19     19     19            19
#                  2_Samuel       20  20  20     20     20     20            20
# מָוֶת            Psalms         22  22  22     22     22     22            22
# מות              2_Kings        23  23  23     23     23     23            23
#                  1_Samuel       27  27  27     27     27     27            27
# שׁחט I           Leviticus      36  36  36     36     36     36            36
#
#                                 lex1  lex_utf81  vs1
# bol_dict_HebArm1 S1
# הרג              Habakkuk          1          1    1
# טַבַּח           Daniel            1          1    0
# מַטְבֵּחַ        Isaiah            1          1    0
# טִבְחָה I        Jeremiah          1          1    0
# מָוֶת            Song_of_songs     1          1    0
# טִבְחָה I        Psalms            1          1    0
# מֹות             Ezra              1          1    0
# מָוֶת            Habakkuk          1          1    0
# מות              Esther            1          1    1
# טַבָּחָה II      1_Samuel          1          1    0
# טבח              1_Samuel          1          1    1
#                  Deuteronomy       1          1    1
#                  Exodus            1          1    1
# טֶבַח I          Genesis           1          1    0
# טבח              Ezekiel           1          1    1
#                  Genesis           1          1    1
# מָוֶת            Exodus            1          1    0
# טבח              Lamentations      1          1    1
# מָוֶת            Esther            1          1    0
# הֶרֶג            Esther            1          1    0
#                  Ezekiel           1          1    0
# מָוֶת            Lamentations      1          1    0
# הֶרֶג            Proverbs          1          1    0
# שׁחט I           Judges            1          1    1
# הרג              Zechariah         1          1    1
# מְמֹותִים        Jeremiah          1          1    0
# שׁחט I           Ezra              1          1    1
# טבח              Psalms            1          1    1
# שׁחט I           1_Kings           1          1    1
# שַׁחֲטָה         Hosea             1          1    0
# טבח              Proverbs          1          1    1
# הרג              Ecclesiastes      1          1    1
# מְמֹותִים        Ezekiel           1          1    0
# טִבְחָה I        1_Samuel          1          1    0
# תְּמוּתָה        Psalms            2          2    0
# מָוֶת            Hosea             2          2    0
# מְרֵמֹות         Ezra              2          2    0
# טַבָּח II        1_Samuel          2          2    0
# טֶבַח I          Proverbs          2          2    0
# הרג              Proverbs          2          2    2
# מָוֶת            1_Chronicles      2          2    0
# הֲרֵגָה          Zechariah         2          2    0
# מָוֶת            Ruth              2          2    0
# הֶרֶג            Isaiah            2          2    0
# הרג              Leviticus         2          2    2
#                  Job               2          2    2
# מות              Ezekiel           2          2    2
#                  Hosea             2          2    2
# הרג              Hosea             2          2    2
# טֶבַח I          Jeremiah          2          2    0
# שׁחט I           Genesis           2          2    2
# מות              Proverbs          2          2    2
# הרג              Deuteronomy       2          2    2
# שׁחט I           Isaiah            3          3    3
#                  2_Kings           3          3    3
# מָוֶת            Joshua            3          3    0
# מות              Job               3          3    3
#                  1_Chronicles      3          3    3
# מָוֶת            Jonah             3          3    0
#                  Leviticus         3          3    0
# מות              Joshua            3          3    3
#                  Isaiah            3          3    3
# הֲרֵגָה          Jeremiah          3          3    0
# מָוֶת            1_Kings           3          3    0
# הרג              1_Chronicles      3          3    3
# שׁחט I           Numbers           3          3    3
# טֶבַח I          Ezekiel           3          3    0
# טבח              Jeremiah          3          3    3
# הרג              Jeremiah          3          3    3
# מָוֶת            Judges            4          4    0
# טֶבַח I          Isaiah            4          4    0
# הרג              Joshua            4          4    4
#                  Amos              4          4    4
# שׁחט I           1_Samuel          4          4    4
# מְרֵמֹות         Nehemiah          4          4    0
# הרג              Lamentations      4          4    4
#                  Nehemiah          4          4    4
#                  2_Kings           5          5    5
# מות              Psalms            5          5    5
# מָוֶת            Ezekiel           5          5    0
# הרג              1_Samuel          5          5    5
# מות              Genesis           6          6    6
# שׁחט I           Exodus            6          6    6
#                  Ezekiel           6          6    6
#                  Jeremiah          6          6    6
# מָוֶת            1_Samuel          6          6    0
#                  2_Kings           6          6    0
# טַבָּח II        Genesis           6          6    0
# מָוֶת            Ecclesiastes      6          6    0
#                  Genesis           7          7    0
#                  2_Chronicles      7          7    0
# טַבָּח II        2_Kings           7          7    0
# מָוֶת            Isaiah            8          8    0
# הרג              2_Samuel          8          8    8
# מָוֶת            Job               8          8    0
# שׁחט I           2_Chronicles      8          8    8
# הרג              Isaiah            9          9    9
# מות              Judges            9          9    9
# הרג              Psalms            9          9    9
# מָוֶת            Deuteronomy       9          9    0
#                  2_Samuel          9          9    0
#                  Numbers           9          9    0
# הרג              Esther            9          9    9
#                  Ezekiel          10         10   10
#                  1_Kings          11         11   11
#                  Numbers          11         11   11
#                  Exodus           11         11   11
# מות              Deuteronomy      11         11   11
#                  2_Chronicles     12         12   12
# הרג              2_Chronicles     12         12   12
# מָוֶת            Jeremiah         13         13    0
# מות              Exodus           15         15   15
#                  Leviticus        16         16   16
#                  Numbers          16         16   16
# הרג              Genesis          16         16   16
#                  Judges           16         16   16
# מות              Jeremiah         17         17   17
# טַבָּח II        Jeremiah         17         17    0
# מָוֶת            Proverbs         19         19    0
# מות              1_Kings          19         19   19
#                  2_Samuel         20         20   20
# מָוֶת            Psalms           22         22    0
# מות              2_Kings          23         23   23
#                  1_Samuel         27         27   27
# שׁחט I           Leviticus        36         36   36

# %%
figure(num=None, figsize=(5, 5), dpi=80, facecolor='w', edgecolor='k')
JerSlaughterWords.groupby("bol_dict_HebArm1").size().sort_values(ascending=True).plot.barh()
plt.xlabel('number of occurence')
plt.ylabel('TNK books')
plt.title('distribution of verbs and nouns of life extinction')
plt.show()

# %%
(JerSlaughterWords[JerSlaughterWords['lex1']=='HRG[']).S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %%
(JerSlaughterWords[JerSlaughterWords['lex1']=='VBX[']).S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140)
plt.show()

# %%
JerSlaughterWords[JerSlaughterWords['lex1']=='CXV['].groupby(['S1']).count().sort_values(['R'], ascending=False)
# Out:
#                R  S2  S3  NODE1  TYPE1  TEXT1  bol_dict_EN1  bol_dict_HebArm1  \
# S1
# Leviticus     36  36  36     36     36     36            36                36
# 2_Chronicles   8   8   8      8      8      8             8                 8
# Exodus         6   6   6      6      6      6             6                 6
# Ezekiel        6   6   6      6      6      6             6                 6
# Jeremiah       6   6   6      6      6      6             6                 6
# 1_Samuel       4   4   4      4      4      4             4                 4
# 2_Kings        3   3   3      3      3      3             3                 3
# Isaiah         3   3   3      3      3      3             3                 3
# Numbers        3   3   3      3      3      3             3                 3
# Genesis        2   2   2      2      2      2             2                 2
# 1_Kings        1   1   1      1      1      1             1                 1
# Ezra           1   1   1      1      1      1             1                 1
# Judges         1   1   1      1      1      1             1                 1
#
#               lex1  lex_utf81  vs1
# S1
# Leviticus       36         36   36
# 2_Chronicles     8          8    8
# Exodus           6          6    6
# Ezekiel          6          6    6
# Jeremiah         6          6    6
# 1_Samuel         4          4    4
# 2_Kings          3          3    3
# Isaiah           3          3    3
# Numbers          3          3    3
# Genesis          2          2    2
# 1_Kings          1          1    1
# Ezra             1          1    1
# Judges           1          1    1

# %%
(JerSlaughterWords[JerSlaughterWords['lex1']=='CXV[']).S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%', shadow=True, startangle=140, radius=3)
plt.show()

# %%
(JerSlaughterWords).S1.value_counts(sort=False).plot.pie(autopct='%0.1f%%', shadow=True, startangle=-90,radius=5)
plt.show()

# %%
JerSlaughterWords.groupby(['S1']).count().sort_values(['R'], ascending=False)
# Out:
#                 R  S2  S3  NODE1  TYPE1  TEXT1  bol_dict_EN1  \
# S1
# Jeremiah       66  66  66     66     66     66            66
# Leviticus      57  57  57     57     57     57            57
# 1_Samuel       47  47  47     47     47     47            47
# 2_Kings        44  44  44     44     44     44            44
# Psalms         40  40  40     40     40     40            40
# 2_Chronicles   39  39  39     39     39     39            39
# Genesis        39  39  39     39     39     39            39
# Numbers        39  39  39     39     39     39            39
# 2_Samuel       37  37  37     37     37     37            37
# 1_Kings        34  34  34     34     34     34            34
# Exodus         34  34  34     34     34     34            34
# Judges         30  30  30     30     30     30            30
# Isaiah         30  30  30     30     30     30            30
# Ezekiel        29  29  29     29     29     29            29
# Proverbs       27  27  27     27     27     27            27
# Deuteronomy    23  23  23     23     23     23            23
# Job            13  13  13     13     13     13            13
# Esther         12  12  12     12     12     12            12
# Joshua         10  10  10     10     10     10            10
# Nehemiah        8   8   8      8      8      8             8
# 1_Chronicles    8   8   8      8      8      8             8
# Hosea           7   7   7      7      7      7             7
# Ecclesiastes    7   7   7      7      7      7             7
# Lamentations    6   6   6      6      6      6             6
# Ezra            4   4   4      4      4      4             4
# Amos            4   4   4      4      4      4             4
# Jonah           3   3   3      3      3      3             3
# Zechariah       3   3   3      3      3      3             3
# Habakkuk        2   2   2      2      2      2             2
# Ruth            2   2   2      2      2      2             2
# Daniel          1   1   1      1      1      1             1
# Song_of_songs   1   1   1      1      1      1             1
#
#                bol_dict_HebArm1  lex1  lex_utf81  vs1
# S1
# Jeremiah                     66    66         66   29
# Leviticus                    57    57         57   54
# 1_Samuel                     47    47         47   37
# 2_Kings                      44    44         44   31
# Psalms                       40    40         40   15
# 2_Chronicles                 39    39         39   32
# Genesis                      39    39         39   25
# Numbers                      39    39         39   30
# 2_Samuel                     37    37         37   28
# 1_Kings                      34    34         34   31
# Exodus                       34    34         34   33
# Judges                       30    30         30   26
# Isaiah                       30    30         30   15
# Ezekiel                      29    29         29   19
# Proverbs                     27    27         27    5
# Deuteronomy                  23    23         23   14
# Job                          13    13         13    5
# Esther                       12    12         12   10
# Joshua                       10    10         10    7
# Nehemiah                      8     8          8    4
# 1_Chronicles                  8     8          8    6
# Hosea                         7     7          7    4
# Ecclesiastes                  7     7          7    1
# Lamentations                  6     6          6    5
# Ezra                          4     4          4    1
# Amos                          4     4          4    4
# Jonah                         3     3          3    0
# Zechariah                     3     3          3    1
# Habakkuk                      2     2          2    1
# Ruth                          2     2          2    0
# Daniel                        1     1          1    0
# Song_of_songs                 1     1          1    0

# %%
(JerSlaughterWords).S1.value_counts(sort=False).plot.pie(autopct='%1.0f%%',radius=5)
plt.show()
